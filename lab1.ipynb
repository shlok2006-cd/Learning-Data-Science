# %%
print("Hello world")
# Out:
# Hello world

# %%
a=6
b=5
if a>b:
    print("a is greater")
print("b is greater")
# Out:
# a is greater
# b is greater

# %%
a=6
b=5
if a>b:
 print("a is greater")
else:
 print("b is greater")
# Out:
# a is greater

# %%
o = 8

# %%
if a>b:
    print("A is greater than B")
elif b>o:
    print("B is greater than O")
else:
    print("O is greatest")
# Out:
# A is greater than B

# %%
while(b<0):
    print("I am studying python")
    b=b-1

# %%
def message():
    print("Hellow")
message()
# Out:
# Hellow

# %%
def sum(p,q):
    print(p+q)
sum(2,3)
# Out:
# 5

# %%
students =["Shlok","Neupane",1,2,'a',2.212]
for i in students:
  print(i)
# Out:
# Shlok
# Neupane
# 1
# 2
# a
# 2.212

# %%
print(students[-1])
# Out:
# 2.212

# %%
j= input("Enter the value of j")
# Out:
# Enter the value of j 20

# %%
print(j)
# Out:
# 20

# %%
collection = {
       1: "Shlok",
      2:"Lakash",
    3:"Prem",
    4:12345,
    "Shlok":"Neupane"
    
}

# %%
print(collection)
# Out:
# {1: 'Shlok', 2: 'Lakash', 3: 'Prem', 4: 12345, 'Shlok': 'Neupane'}

# %%
print(collection[1])
# Out:
# Shlok

# %%
print(collection["Shlok"])
# Out:
# Neupane

# %%
# !conda install matplotlib -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/shlok/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.12.1                 |       h7934f7d_0         2.8 MB
#     cairo-1.18.4               |       h44eff21_0         728 KB
#     contourpy-1.3.3            |  py313hdb19cb5_0        11.3 MB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     cyrus-sasl-2.1.28          |       h1110e0f_3         242 KB
#     dav1d-1.2.1                |       h5eee18b_0         823 KB
#     fontconfig-2.15.0          |       h2c49b7f_0         262 KB
#     fonttools-4.60.1           |  py313hee96239_0         4.1 MB
# ...
